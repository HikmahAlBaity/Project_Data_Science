# %% [markdown]
# <a href="https://colab.research.google.com/github/HikmahAlBaity/Project_Data_Science/blob/main/1_0_Assignment__1_DS_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/custcat.csv')

# %%
df.head ()
# Out:
#    region  tenure  age  marital  address  income  ed  employ  retire  gender  \
# 0       2      13   44        1        9    64.0   4       5     0.0       0
# 1       3      11   33        1        7   136.0   5       5     0.0       0
# 2       3      68   52        1       24   116.0   1      29     0.0       1
# 3       2      33   33        0       12    33.0   2       0     0.0       1
# 4       2      23   30        1        9    30.0   1       2     0.0       0
#
#    reside  custcat
# 0       2        1
# 1       6        4
# 2       2        3
# 3       1        1
# 4       4        3

# %%
# read first 50 rows in data set
df.head (50)
# Out:
#     region  tenure  age  marital  address  income  ed  employ  retire  gender  \
# 0        2      13   44        1        9    64.0   4       5     0.0       0
# 1        3      11   33        1        7   136.0   5       5     0.0       0
# 2        3      68   52        1       24   116.0   1      29     0.0       1
# 3        2      33   33        0       12    33.0   2       0     0.0       1
# 4        2      23   30        1        9    30.0   1       2     0.0       0
# 5        2      41   39        0       17    78.0   2      16     0.0       1
# 6        3      45   22        1        2    19.0   2       4     0.0       1
# 7        2      38   35        0        5    76.0   2      10     0.0       0
# 8        3      45   59        1        7   166.0   4      31     0.0       0
# 9        1      68   41        1       21    72.0   1      22     0.0       0
# 10       2       5   33        0       10   125.0   4       5     0.0       1
# ...

# %%
# %whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# df         DataFrame         region  tenure  age <...>n[1000 rows x 12 columns]
# pd         module       <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
